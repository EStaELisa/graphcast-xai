# %% [markdown]
# # Run Feature Occlusion

# %%
import xarray as xr

from pkg.feature_occlusion.forecast_with_mask import run_multiple_forecasts_with_mask

# %%
input_path = "../data/prediction_zeynep_22/input_data/graphcast_ready_input_zeynep_22_graphcast_small.nc"
input = xr.open_dataset(input_path)

climatology_path = "../data/data_for_climatology/era5_1979-2015_0218_climatology.nc"
climatology = xr.open_dataset(climatology_path)

# %%
surface_variables = [
    "2m_temperature",
    ("10m_u_component_of_wind",
    "10m_v_component_of_wind"),
    "total_precipitation_6hr",
    "mean_sea_level_pressure",
]

atmospheric_variables = [
    "temperature",
    ("u_component_of_wind",
    "v_component_of_wind"),
    "geopotential",
    "vertical_velocity",
    "specific_humidity",
]

lower_troposphere = (850, 925, 1000)
mid_troposphere = (500, 600, 700)
upper_troposphere = (250, 300, 400)
stratospheric_levels  = (50, 100, 150, 200)

pressure_level_groups = [
    lower_troposphere,
    mid_troposphere,
    upper_troposphere,
    stratospheric_levels,
]

pressure_levels = [
    1000, 925, 850, 700, 600, 500, 400, 300, 250, 200, 150, 100, 50
]

# regions = [
#     "atlantic_jet_stream",
#     "storm_core_10utc",
#     "storm_core_16utc",
#     ("storm_core_10utc", "storm_core_16utc"),
#     "dynamic_uljs",
#     "storm_region",
#     "high_pressure_south",
#     "low_pressure_north",
#     "north_germany"
# ]

regions = [
    "atlantic_jet_stream",
    "storm_core",
    "dynamic_uljs",
    "storm_region",
    "high_pressure_south",
    "low_pressure_north",
    "north_germany"
]

# %% [markdown]
# ## Surface Variables

# %%
run_multiple_forecasts_with_mask(
    input_data=input,
    climatology=climatology,
    predictions_folder="../data/feature_occlusion/surface_variables",
    variable_groups=surface_variables
)

# %% [markdown]
# ## Atmospheric Variables

# %%
run_multiple_forecasts_with_mask(
    input_data=input,
    climatology=climatology,
    predictions_folder="../data/feature_occlusion/atmospheric_variables",
    variable_groups=atmospheric_variables
)

# %% [markdown]
# ## Pressure Level Zones

# %%
run_multiple_forecasts_with_mask(
    input_data=input,
    climatology=climatology,
    predictions_folder="../data/feature_occlusion/pressure_level_groups",
    pressure_levels=pressure_level_groups
)

# %% [markdown]
# ## All pressure Levels

# %%
run_multiple_forecasts_with_mask(
    input_data=input,
    climatology=climatology,
    predictions_folder="../data/feature_occlusion/pressure_levels",
    pressure_levels=pressure_levels
)

# %% [markdown]
# ## Spacial Regions

# %%
run_multiple_forecasts_with_mask(
    input_data=input,
    climatology=climatology,
    predictions_folder="../data/feature_occlusion/spatial_regions",
    regions=regions
)

# %%
run_multiple_forecasts_with_mask(
    input_data=input,
    climatology=climatology,
    predictions_folder="../data/feature_occlusion/spatial_regions",
    regions=["storm_core"]
)
# Out:
# 🚀 Running forecast with mask on: vars=None, levels=None, regions=storm_core, time_steps=None
#    → About to call run_forecast_with_mask with regs = 'storm_core'
# ‼ run_forecast_with_mask FAILED for regs = 'storm_core'
#    Exception message: dimensions cannot change for in-place operations
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 run_multiple_forecasts_with_mask(
#       2     input_data=input,
#       3     climatology=climatology,
#       4     predictions_folder="../data/feature_occlusion/spatial_regions",
#       5     regions=["storm_core"]
#       6 )
#
# File ~/Tech/Bachelorarbeit/graphcast-xai/pkg/feature_occlusion/forecast_with_mask.py:166, in run_multiple_forecasts_with_mask(input_data, climatology, predictions_folder, variable_groups, pressure_levels, regions, time_steps, model, upload_to_gcs)
#     164 # Wrap in try/except to catch index errors and see which `regs` fails
#     165 try:
# --> 166     run_forecast_with_mask(
#     167         input_data=input_data,
#     168         climatology=climatology,
#     169         output_name=output_name,
#     170         predictions_folder=predictions_folder,
#     171         variables=variables_list,
#     172         pressure_levels=levels_list,
#     173         regions=regions_list,
#     174         time_steps=steps_list,
#     175         model=model,
#     176         upload_to_gcs=upload_to_gcs,
#     177     )
#     179 except Exception as e:
#     180     print(f"‼ run_forecast_with_mask FAILED for regs = {regs!r}")
#
# File ~/Tech/Bachelorarbeit/graphcast-xai/pkg/feature_occlusion/forecast_with_mask.py:52, in run_forecast_with_mask(input_data, climatology, output_name, predictions_folder, variables, pressure_levels, regions, time_steps, model, upload_to_gcs)
#      24 """
#      25 Runs a GraphCast forecast using masked input data.
#      26
#    (...)     49 None
#      50 """
#      51 # Make mask
# ---> 52 mask = create_feature_mask(input_data, variables, pressure_levels, regions, time_steps)
#      54 # apply mask to input data
#      55 masked_input = apply_mask_to_input(
#      56     input_data=input_data,
#      57     climatology_data=climatology,
#      58     mask=mask,
#      59 )
#
# File ~/Tech/Bachelorarbeit/graphcast-xai/pkg/mask/generate_mask.py:86, in create_feature_mask(ds, variables, pressure_levels, regions, time_steps)
#      84     b16 = c16.broadcast_like(ds[var])
#      85     combo = (~t0 & ~t1) | (t0 & b10) | (t1 & b16)
# ---> 86     spatial &= combo
#      88 # (b) individual fixed‐time storm cores
#      89 elif region in ("storm_core_10utc", "storm_core_16utc"):
#
# File ~/Tech/Bachelorarbeit/graphcast-xai/.venv/lib/python3.12/site-packages/xarray/core/_typed_ops.py:793, in DataArrayOpsMixin.__iand__(self, other)
#     792 def __iand__(self, other: DaCompatible) -> Self:  # type:ignore[misc]
# --> 793     return self._inplace_binary_op(other, operator.iand)
#
# File ~/Tech/Bachelorarbeit/graphcast-xai/.venv/lib/python3.12/site-packages/xarray/core/dataarray.py:4874, in DataArray._inplace_binary_op(self, other, f)
#    4872 try:
#    4873     with self.coords._merge_inplace(other_coords):
# -> 4874         f(self.variable, other_variable)
#    4875 except MergeError as exc:
#    4876     raise MergeError(
#    4877         "Automatic alignment is not supported for in-place operations.\n"
#    4878         "Consider aligning the indices manually or using a not-in-place operation.\n"
#    4879         "See https://github.com/pydata/xarray/issues/3910 for more explanations."
#    4880     ) from exc
#
# File ~/Tech/Bachelorarbeit/graphcast-xai/.venv/lib/python3.12/site-packages/xarray/core/_typed_ops.py:1221, in VariableOpsMixin.__iand__(self, other)
#    1220 def __iand__(self, other: VarCompatible) -> Self:  # type:ignore[misc]
# -> 1221     return self._inplace_binary_op(other, operator.iand)
#
# File ~/Tech/Bachelorarbeit/graphcast-xai/.venv/lib/python3.12/site-packages/xarray/core/variable.py:2349, in Variable._inplace_binary_op(self, other, f)
#    2347 self_data, other_data, dims = _broadcast_compat_data(self, other)
#    2348 if dims != self.dims:
# -> 2349     raise ValueError("dimensions cannot change for in-place operations")
#    2350 with np.errstate(all="ignore"):
#    2351     self.values = f(self_data, other_data)
#
# ValueError: dimensions cannot change for in-place operations

# %% [markdown]
# ## Time Steps

# %%
run_multiple_forecasts_with_mask(
    input_data=input,
    climatology=climatology,
    predictions_folder="../data/feature_occlusion/time_steps",
    time_steps=[0, 1]
)

# %% [markdown]
# # Multiple Features

# %% [markdown]
# ## Pressure Level Groups and Atmospheric Variables

# %%
run_multiple_forecasts_with_mask(
    input_data=input,
    climatology=climatology,
    predictions_folder="../data/feature_occlusion/pressure_level_groups_atmospheric_variables",
    pressure_levels=pressure_level_groups,
    variable_groups=atmospheric_variables
)

# %% [markdown]
# ## Regions and Surface Variables

# %%
run_multiple_forecasts_with_mask(
    input_data=input,
    climatology=climatology,
    predictions_folder="../data/feature_occlusion/regions_surface_variables",
    regions=regions,
    variable_groups=surface_variables
)

# %%
regions = [
    "dynamic_uljs"
]

run_multiple_forecasts_with_mask(
    input_data=input,
    climatology=climatology,
    predictions_folder="../data/feature_occlusion/regions_surface_variables",
    regions=regions,
    variable_groups=surface_variables
)

# %%
regions = [
    "storm_core"
]

run_multiple_forecasts_with_mask(
    input_data=input,
    climatology=climatology,
    predictions_folder="../data/feature_occlusion/regions_surface_variables",
    regions=regions,
    variable_groups=surface_variables
)
# Out:
# 🚀 Running forecast with mask on: vars=2m_temperature, levels=None, regions=storm_core, time_steps=None
#    → About to call run_forecast_with_mask with regs = 'storm_core'
# 📦 Using checkpoint: graphcast/params/GraphCast_small - ERA5 1979-2015 - resolution 1.0 - pressure levels 13 - mesh 2to5 - precipitation input and output.npz
# /Users/estakempf/Tech/Bachelorarbeit/graphcast-xai/.venv/lib/python3.12/site-packages/graphcast/rollout.py:127: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   num_target_steps = targets_template.dims["time"]
# /Users/estakempf/Tech/Bachelorarbeit/graphcast-xai/.venv/lib/python3.12/site-packages/graphcast/autoregressive.py:202: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   scan_length = targets_template.dims['time']
# WARNING:absl:Skipping gradient checkpointing for sequence length of 1
# /Users/estakempf/Tech/Bachelorarbeit/graphcast-xai/.venv/lib/python3.12/site-packages/graphcast/autoregressive.py:115: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   num_inputs = inputs.dims['time']
# /Users/estakempf/Tech/Bachelorarbeit/graphcast-xai/.venv/lib/python3.12/site-packages/graphcast/rollout.py:205: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   num_inputs = prev_inputs.dims["time"]
# ✅ Prediction saved to: ../data/feature_occlusion/regions_surface_variables/masked_2m_temperature_levnone_regstorm_core_tnone.nc
# 🚀 Running forecast with mask on: vars=('10m_u_component_of_wind', '10m_v_component_of_wind'), levels=None, regions=storm_core, time_steps=None
#    → About to call run_forecast_with_mask with regs = 'storm_core'
# 📦 Using checkpoint: graphcast/params/GraphCast_small - ERA5 1979-2015 - resolution 1.0 - pressure levels 13 - mesh 2to5 - precipitation input and output.npz
# /Users/estakempf/Tech/Bachelorarbeit/graphcast-xai/.venv/lib/python3.12/site-packages/graphcast/rollout.py:127: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   num_target_steps = targets_template.dims["time"]
# /Users/estakempf/Tech/Bachelorarbeit/graphcast-xai/.venv/lib/python3.12/site-packages/graphcast/autoregressive.py:202: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   scan_length = targets_template.dims['time']
# WARNING:absl:Skipping gradient checkpointing for sequence length of 1
# /Users/estakempf/Tech/Bachelorarbeit/graphcast-xai/.venv/lib/python3.12/site-packages/graphcast/autoregressive.py:115: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   num_inputs = inputs.dims['time']
# /Users/estakempf/Tech/Bachelorarbeit/graphcast-xai/.venv/lib/python3.12/site-packages/graphcast/rollout.py:205: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   num_inputs = prev_inputs.dims["time"]
# ✅ Prediction saved to: ../data/feature_occlusion/regions_surface_variables/masked_('10m_u_component_of_wind', '10m_v_component_of_wind')_levnone_regstorm_core_tnone.nc
# 🚀 Running forecast with mask on: vars=total_precipitation_6hr, levels=None, regions=storm_core, time_steps=None
#    → About to call run_forecast_with_mask with regs = 'storm_core'
# 📦 Using checkpoint: graphcast/params/GraphCast_small - ERA5 1979-2015 - resolution 1.0 - pressure levels 13 - mesh 2to5 - precipitation input and output.npz
# /Users/estakempf/Tech/Bachelorarbeit/graphcast-xai/.venv/lib/python3.12/site-packages/graphcast/rollout.py:127: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   num_target_steps = targets_template.dims["time"]
# /Users/estakempf/Tech/Bachelorarbeit/graphcast-xai/.venv/lib/python3.12/site-packages/graphcast/autoregressive.py:202: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   scan_length = targets_template.dims['time']
# WARNING:absl:Skipping gradient checkpointing for sequence length of 1
# /Users/estakempf/Tech/Bachelorarbeit/graphcast-xai/.venv/lib/python3.12/site-packages/graphcast/autoregressive.py:115: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   num_inputs = inputs.dims['time']
# /Users/estakempf/Tech/Bachelorarbeit/graphcast-xai/.venv/lib/python3.12/site-packages/graphcast/rollout.py:205: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   num_inputs = prev_inputs.dims["time"]
# ✅ Prediction saved to: ../data/feature_occlusion/regions_surface_variables/masked_total_precipitation_6hr_levnone_regstorm_core_tnone.nc
# 🚀 Running forecast with mask on: vars=mean_sea_level_pressure, levels=None, regions=storm_core, time_steps=None
#    → About to call run_forecast_with_mask with regs = 'storm_core'
# 📦 Using checkpoint: graphcast/params/GraphCast_small - ERA5 1979-2015 - resolution 1.0 - pressure levels 13 - mesh 2to5 - precipitation input and output.npz
# /Users/estakempf/Tech/Bachelorarbeit/graphcast-xai/.venv/lib/python3.12/site-packages/graphcast/rollout.py:127: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   num_target_steps = targets_template.dims["time"]
# /Users/estakempf/Tech/Bachelorarbeit/graphcast-xai/.venv/lib/python3.12/site-packages/graphcast/autoregressive.py:202: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   scan_length = targets_template.dims['time']
# WARNING:absl:Skipping gradient checkpointing for sequence length of 1
# /Users/estakempf/Tech/Bachelorarbeit/graphcast-xai/.venv/lib/python3.12/site-packages/graphcast/autoregressive.py:115: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   num_inputs = inputs.dims['time']
# /Users/estakempf/Tech/Bachelorarbeit/graphcast-xai/.venv/lib/python3.12/site-packages/graphcast/rollout.py:205: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   num_inputs = prev_inputs.dims["time"]
# ✅ Prediction saved to: ../data/feature_occlusion/regions_surface_variables/masked_mean_sea_level_pressure_levnone_regstorm_core_tnone.nc

# %% [markdown]
# ## Regions and Atmospheric Variables

# %%
run_multiple_forecasts_with_mask(
    input_data=input,
    climatology=climatology,
    predictions_folder="../data/feature_occlusion/regions_atmospheric_variables",
    regions=regions,
    variable_groups=atmospheric_variables
)

# %%
regions = [
    "storm_core",
    "dynamic_uljs"
]

run_multiple_forecasts_with_mask(
    input_data=input,
    climatology=climatology,
    predictions_folder="../data/feature_occlusion/regions_atmospheric_variables",
    regions=regions,
    variable_groups=atmospheric_variables
)

# %% [markdown]
# ## Storm Sub Boxes

# %%
storm_sub_boxes = [
    "quad_nw",
    "quad_ne",
    "quad_sw",
    "quad_se",
]

# %%
run_multiple_forecasts_with_mask(
    input_data=input,
    climatology=climatology,
    predictions_folder="../data/feature_occlusion/storm_sub_boxes",
    regions=storm_sub_boxes
)

# %%
run_multiple_forecasts_with_mask(
    input_data=input,
    climatology=climatology,
    predictions_folder="../data/feature_occlusion/storm_sub_boxes_surface_variables",
    regions=storm_sub_boxes,
    variable_groups=surface_variables
)

# %%
run_multiple_forecasts_with_mask(
    input_data=input,
    climatology=climatology,
    predictions_folder="../data/feature_occlusion/storm_sub_boxes_atmospheric_variables",
    regions=storm_sub_boxes,
    variable_groups=atmospheric_variables
)
