# %% [markdown]
# # Run Feature Occlusion

# %%
import xarray as xr

from pkg.feature_occlusion.forecast_with_mask import run_multiple_forecasts_with_mask

# %%
input_path = "../data/prediction_zeynep_22/input_data/graphcast_ready_input_zeynep_22_graphcast_small.nc"
input = xr.open_dataset(input_path)

climatology_path = "../data/data_for_climatology/era5_1979-2015_0218_climatology.nc"
climatology = xr.open_dataset(climatology_path)

# %%
surface_variables = [
    "2m_temperature",
    ("10m_u_component_of_wind",
    "10m_v_component_of_wind"),
    "total_precipitation_6hr",
    "mean_sea_level_pressure",
]

atmospheric_variables = [
    "temperature",
    ("u_component_of_wind",
    "v_component_of_wind"),
    "geopotential",
    "vertical_velocity",
    "specific_humidity",
]

lower_troposphere = (850, 925, 1000)
mid_troposphere = (500, 600, 700)
upper_troposphere = (250, 300, 400)
stratospheric_levels  = (50, 100, 150, 200)

pressure_level_groups = [
    lower_troposphere,
    mid_troposphere,
    upper_troposphere,
    stratospheric_levels,
]

pressure_levels = [
    1000, 925, 850, 700, 600, 500, 400, 300, 250, 200, 150, 100, 50
]

# regions = [
#     "atlantic_jet_stream",
#     "storm_core_10utc",
#     "storm_core_16utc",
#     ("storm_core_10utc", "storm_core_16utc"),
#     "dynamic_uljs",
#     "storm_region",
#     "high_pressure_south",
#     "low_pressure_north",
#     "north_germany"
# ]

regions = [
    "atlantic_jet_stream",
    "storm_core",
    "dynamic_uljs",
    "high_pressure_south",
    "low_pressure_north",
]

# %% [markdown]
# ## Surface Variables

# %%
run_multiple_forecasts_with_mask(
    input_data=input,
    climatology=climatology,
    predictions_folder="../data/feature_occlusion/surface_variables",
    variable_groups=surface_variables
)

# %% [markdown]
# ## Atmospheric Variables

# %%
run_multiple_forecasts_with_mask(
    input_data=input,
    climatology=climatology,
    predictions_folder="../data/feature_occlusion/atmospheric_variables",
    variable_groups=atmospheric_variables
)

# %% [markdown]
# ## Pressure Level Zones

# %%
run_multiple_forecasts_with_mask(
    input_data=input,
    climatology=climatology,
    predictions_folder="../data/feature_occlusion/pressure_level_groups",
    pressure_levels=pressure_level_groups
)

# %% [markdown]
# ## All pressure Levels

# %%
run_multiple_forecasts_with_mask(
    input_data=input,
    climatology=climatology,
    predictions_folder="../data/feature_occlusion/pressure_levels",
    pressure_levels=pressure_levels
)

# %% [markdown]
# ## Spacial Regions

# %%
run_multiple_forecasts_with_mask(
    input_data=input,
    climatology=climatology,
    predictions_folder="../data/feature_occlusion/spatial_regions",
    regions=regions
)

# %% [markdown]
# ## Time Steps

# %%
run_multiple_forecasts_with_mask(
    input_data=input,
    climatology=climatology,
    predictions_folder="../data/feature_occlusion/time_steps",
    time_steps=[0, 1]
)

# %% [markdown]
# # Multiple Features

# %% [markdown]
# ## Pressure Level Groups and Atmospheric Variables

# %%
run_multiple_forecasts_with_mask(
    input_data=input,
    climatology=climatology,
    predictions_folder="../data/feature_occlusion/pressure_level_groups_atmospheric_variables",
    pressure_levels=pressure_level_groups,
    variable_groups=atmospheric_variables
)

# %% [markdown]
# ## Regions and Surface Variables

# %%
run_multiple_forecasts_with_mask(
    input_data=input,
    climatology=climatology,
    predictions_folder="../data/feature_occlusion/regions_surface_variables",
    regions=regions,
    variable_groups=surface_variables
)

# %% [markdown]
# ## Regions and Atmospheric Variables

# %%
run_multiple_forecasts_with_mask(
    input_data=input,
    climatology=climatology,
    predictions_folder="../data/feature_occlusion/regions_atmospheric_variables",
    regions=regions,
    variable_groups=atmospheric_variables
)

# %% [markdown]
# ## Regions + Selected Variables + Time steps

# %%
selected_regions = [
    "storm_core_10utc",
    "storm_core_16utc"
]

selected_variables = [
    ("10m_u_component_of_wind", "10m_v_component_of_wind"),
    "mean_sea_level_pressure",
    ("u_component_of_wind", "v_component_of_wind"),
    "geopotential",
]

run_multiple_forecasts_with_mask(
    input_data=input,
    climatology=climatology,
    predictions_folder="../data/feature_occlusion/selected_regions_variables_time",
    regions=selected_regions,
    variable_groups=selected_variables
)

# %%
selected_regions = [
    "storm_core",
    "dynamic_uljs"
]

selected_variables = [
    ("10m_u_component_of_wind", "10m_v_component_of_wind"),
    "mean_sea_level_pressure",
    ("u_component_of_wind", "v_component_of_wind"),
    "geopotential",
]

run_multiple_forecasts_with_mask(
    input_data=input,
    climatology=climatology,
    predictions_folder="../data/feature_occlusion/selected_regions_variables_time_new",
    regions=selected_regions,
    variable_groups=selected_variables,
    time_steps=[0, 1]
)

# %% [markdown]
# ## Atmospheric Variables + Pressure Levels

# %%
run_multiple_forecasts_with_mask(
    input_data=input,
    climatology=climatology,
    predictions_folder="../data/feature_occlusion/atmospheric_variables_levels",
    variable_groups=atmospheric_variables,
    pressure_levels=pressure_levels
)

# %% [markdown]
# ## Wind Speed and Geopotential -> Pressure Levels and Regions

# %%
run_multiple_forecasts_with_mask(
    input_data=input,
    climatology=climatology,
    predictions_folder="../data/feature_occlusion/geopotential_levels_regions",
    variable_groups=["geopotential"],
    regions=regions,
    pressure_levels=pressure_levels
)

# %%
run_multiple_forecasts_with_mask(
    input_data=input,
    climatology=climatology,
    predictions_folder="../data/feature_occlusion/wind_levels_regions",
    variable_groups=[
        ("u_component_of_wind", "v_component_of_wind"),
    ],
    regions=regions,
    pressure_levels=pressure_levels
)
# Out:
# 🚀 Running forecast with mask on: vars=('u_component_of_wind', 'v_component_of_wind'), levels=1000, regions=atlantic_jet_stream, time_steps=None
# 📦 Using checkpoint: graphcast/params/GraphCast_small - ERA5 1979-2015 - resolution 1.0 - pressure levels 13 - mesh 2to5 - precipitation input and output.npz
# /Users/estakempf/Tech/Bachelorarbeit/graphcast-xai/.venv/lib/python3.12/site-packages/graphcast/rollout.py:127: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   num_target_steps = targets_template.dims["time"]
# /Users/estakempf/Tech/Bachelorarbeit/graphcast-xai/.venv/lib/python3.12/site-packages/graphcast/autoregressive.py:202: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   scan_length = targets_template.dims['time']
# WARNING:absl:Skipping gradient checkpointing for sequence length of 1
# /Users/estakempf/Tech/Bachelorarbeit/graphcast-xai/.venv/lib/python3.12/site-packages/graphcast/autoregressive.py:115: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   num_inputs = inputs.dims['time']
# /Users/estakempf/Tech/Bachelorarbeit/graphcast-xai/.venv/lib/python3.12/site-packages/graphcast/rollout.py:205: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   num_inputs = prev_inputs.dims["time"]
# Prediction saved to: ../data/feature_occlusion/wind_levels_regions/masked_('u_component_of_wind', 'v_component_of_wind')_lev1000_regatlantic_jet_stream_tnone.nc
# 🚀 Running forecast with mask on: vars=('u_component_of_wind', 'v_component_of_wind'), levels=1000, regions=storm_core, time_steps=None
# 📦 Using checkpoint: graphcast/params/GraphCast_small - ERA5 1979-2015 - resolution 1.0 - pressure levels 13 - mesh 2to5 - precipitation input and output.npz
# /Users/estakempf/Tech/Bachelorarbeit/graphcast-xai/.venv/lib/python3.12/site-packages/graphcast/rollout.py:127: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   num_target_steps = targets_template.dims["time"]
# /Users/estakempf/Tech/Bachelorarbeit/graphcast-xai/.venv/lib/python3.12/site-packages/graphcast/autoregressive.py:202: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   scan_length = targets_template.dims['time']
# WARNING:absl:Skipping gradient checkpointing for sequence length of 1
# /Users/estakempf/Tech/Bachelorarbeit/graphcast-xai/.venv/lib/python3.12/site-packages/graphcast/autoregressive.py:115: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   num_inputs = inputs.dims['time']
# /Users/estakempf/Tech/Bachelorarbeit/graphcast-xai/.venv/lib/python3.12/site-packages/graphcast/rollout.py:205: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   num_inputs = prev_inputs.dims["time"]
# Prediction saved to: ../data/feature_occlusion/wind_levels_regions/masked_('u_component_of_wind', 'v_component_of_wind')_lev1000_regstorm_core_tnone.nc
# 🚀 Running forecast with mask on: vars=('u_component_of_wind', 'v_component_of_wind'), levels=1000, regions=dynamic_uljs, time_steps=None
# 📦 Using checkpoint: graphcast/params/GraphCast_small - ERA5 1979-2015 - resolution 1.0 - pressure levels 13 - mesh 2to5 - precipitation input and output.npz
# /Users/estakempf/Tech/Bachelorarbeit/graphcast-xai/.venv/lib/python3.12/site-packages/graphcast/rollout.py:127: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   num_target_steps = targets_template.dims["time"]
# /Users/estakempf/Tech/Bachelorarbeit/graphcast-xai/.venv/lib/python3.12/site-packages/graphcast/autoregressive.py:202: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   scan_length = targets_template.dims['time']
# WARNING:absl:Skipping gradient checkpointing for sequence length of 1
# /Users/estakempf/Tech/Bachelorarbeit/graphcast-xai/.venv/lib/python3.12/site-packages/graphcast/autoregressive.py:115: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   num_inputs = inputs.dims['time']
# /Users/estakempf/Tech/Bachelorarbeit/graphcast-xai/.venv/lib/python3.12/site-packages/graphcast/rollout.py:205: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   num_inputs = prev_inputs.dims["time"]
# Prediction saved to: ../data/feature_occlusion/wind_levels_regions/masked_('u_component_of_wind', 'v_component_of_wind')_lev1000_regdynamic_uljs_tnone.nc
# 🚀 Running forecast with mask on: vars=('u_component_of_wind', 'v_component_of_wind'), levels=1000, regions=high_pressure_south, time_steps=None
# 📦 Using checkpoint: graphcast/params/GraphCast_small - ERA5 1979-2015 - resolution 1.0 - pressure levels 13 - mesh 2to5 - precipitation input and output.npz
# /Users/estakempf/Tech/Bachelorarbeit/graphcast-xai/.venv/lib/python3.12/site-packages/graphcast/rollout.py:127: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   num_target_steps = targets_template.dims["time"]
# /Users/estakempf/Tech/Bachelorarbeit/graphcast-xai/.venv/lib/python3.12/site-packages/graphcast/autoregressive.py:202: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   scan_length = targets_template.dims['time']
# WARNING:absl:Skipping gradient checkpointing for sequence length of 1
# /Users/estakempf/Tech/Bachelorarbeit/graphcast-xai/.venv/lib/python3.12/site-packages/graphcast/autoregressive.py:115: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   num_inputs = inputs.dims['time']
# /Users/estakempf/Tech/Bachelorarbeit/graphcast-xai/.venv/lib/python3.12/site-packages/graphcast/rollout.py:205: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   num_inputs = prev_inputs.dims["time"]
# Prediction saved to: ../data/feature_occlusion/wind_levels_regions/masked_('u_component_of_wind', 'v_component_of_wind')_lev1000_reghigh_pressure_south_tnone.nc
# 🚀 Running forecast with mask on: vars=('u_component_of_wind', 'v_component_of_wind'), levels=1000, regions=low_pressure_north, time_steps=None
# 📦 Using checkpoint: graphcast/params/GraphCast_small - ERA5 1979-2015 - resolution 1.0 - pressure levels 13 - mesh 2to5 - precipitation input and output.npz
# /Users/estakempf/Tech/Bachelorarbeit/graphcast-xai/.venv/lib/python3.12/site-packages/graphcast/rollout.py:127: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   num_target_steps = targets_template.dims["time"]
# /Users/estakempf/Tech/Bachelorarbeit/graphcast-xai/.venv/lib/python3.12/site-packages/graphcast/autoregressive.py:202: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   scan_length = targets_template.dims['time']
# WARNING:absl:Skipping gradient checkpointing for sequence length of 1
# /Users/estakempf/Tech/Bachelorarbeit/graphcast-xai/.venv/lib/python3.12/site-packages/graphcast/autoregressive.py:115: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   num_inputs = inputs.dims['time']
# /Users/estakempf/Tech/Bachelorarbeit/graphcast-xai/.venv/lib/python3.12/site-packages/graphcast/rollout.py:205: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   num_inputs = prev_inputs.dims["time"]
# Prediction saved to: ../data/feature_occlusion/wind_levels_regions/masked_('u_component_of_wind', 'v_component_of_wind')_lev1000_reglow_pressure_north_tnone.nc
# 🚀 Running forecast with mask on: vars=('u_component_of_wind', 'v_component_of_wind'), levels=925, regions=atlantic_jet_stream, time_steps=None
# 📦 Using checkpoint: graphcast/params/GraphCast_small - ERA5 1979-2015 - resolution 1.0 - pressure levels 13 - mesh 2to5 - precipitation input and output.npz
# /Users/estakempf/Tech/Bachelorarbeit/graphcast-xai/.venv/lib/python3.12/site-packages/graphcast/rollout.py:127: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   num_target_steps = targets_template.dims["time"]
# /Users/estakempf/Tech/Bachelorarbeit/graphcast-xai/.venv/lib/python3.12/site-packages/graphcast/autoregressive.py:202: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   scan_length = targets_template.dims['time']
# WARNING:absl:Skipping gradient checkpointing for sequence length of 1
# /Users/estakempf/Tech/Bachelorarbeit/graphcast-xai/.venv/lib/python3.12/site-packages/graphcast/autoregressive.py:115: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   num_inputs = inputs.dims['time']
# /Users/estakempf/Tech/Bachelorarbeit/graphcast-xai/.venv/lib/python3.12/site-packages/graphcast/rollout.py:205: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   num_inputs = prev_inputs.dims["time"]
# Prediction saved to: ../data/feature_occlusion/wind_levels_regions/masked_('u_component_of_wind', 'v_component_of_wind')_lev925_regatlantic_jet_stream_tnone.nc
# 🚀 Running forecast with mask on: vars=('u_component_of_wind', 'v_component_of_wind'), levels=925, regions=storm_core, time_steps=None
# 📦 Using checkpoint: graphcast/params/GraphCast_small - ERA5 1979-2015 - resolution 1.0 - pressure levels 13 - mesh 2to5 - precipitation input and output.npz
# /Users/estakempf/Tech/Bachelorarbeit/graphcast-xai/.venv/lib/python3.12/site-packages/graphcast/rollout.py:127: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   num_target_steps = targets_template.dims["time"]
# /Users/estakempf/Tech/Bachelorarbeit/graphcast-xai/.venv/lib/python3.12/site-packages/graphcast/autoregressive.py:202: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   scan_length = targets_template.dims['time']
# WARNING:absl:Skipping gradient checkpointing for sequence length of 1
# /Users/estakempf/Tech/Bachelorarbeit/graphcast-xai/.venv/lib/python3.12/site-packages/graphcast/autoregressive.py:115: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   num_inputs = inputs.dims['time']
# /Users/estakempf/Tech/Bachelorarbeit/graphcast-xai/.venv/lib/python3.12/site-packages/graphcast/rollout.py:205: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   num_inputs = prev_inputs.dims["time"]
# Prediction saved to: ../data/feature_occlusion/wind_levels_regions/masked_('u_component_of_wind', 'v_component_of_wind')_lev925_regstorm_core_tnone.nc
# 🚀 Running forecast with mask on: vars=('u_component_of_wind', 'v_component_of_wind'), levels=925, regions=dynamic_uljs, time_steps=None
# 📦 Using checkpoint: graphcast/params/GraphCast_small - ERA5 1979-2015 - resolution 1.0 - pressure levels 13 - mesh 2to5 - precipitation input and output.npz
# /Users/estakempf/Tech/Bachelorarbeit/graphcast-xai/.venv/lib/python3.12/site-packages/graphcast/rollout.py:127: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   num_target_steps = targets_template.dims["time"]
# /Users/estakempf/Tech/Bachelorarbeit/graphcast-xai/.venv/lib/python3.12/site-packages/graphcast/autoregressive.py:202: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   scan_length = targets_template.dims['time']
# WARNING:absl:Skipping gradient checkpointing for sequence length of 1
# /Users/estakempf/Tech/Bachelorarbeit/graphcast-xai/.venv/lib/python3.12/site-packages/graphcast/autoregressive.py:115: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   num_inputs = inputs.dims['time']
# /Users/estakempf/Tech/Bachelorarbeit/graphcast-xai/.venv/lib/python3.12/site-packages/graphcast/rollout.py:205: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   num_inputs = prev_inputs.dims["time"]
# Prediction saved to: ../data/feature_occlusion/wind_levels_regions/masked_('u_component_of_wind', 'v_component_of_wind')_lev925_regdynamic_uljs_tnone.nc
# 🚀 Running forecast with mask on: vars=('u_component_of_wind', 'v_component_of_wind'), levels=925, regions=high_pressure_south, time_steps=None
# 📦 Using checkpoint: graphcast/params/GraphCast_small - ERA5 1979-2015 - resolution 1.0 - pressure levels 13 - mesh 2to5 - precipitation input and output.npz
# /Users/estakempf/Tech/Bachelorarbeit/graphcast-xai/.venv/lib/python3.12/site-packages/graphcast/rollout.py:127: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   num_target_steps = targets_template.dims["time"]
# /Users/estakempf/Tech/Bachelorarbeit/graphcast-xai/.venv/lib/python3.12/site-packages/graphcast/autoregressive.py:202: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   scan_length = targets_template.dims['time']
# WARNING:absl:Skipping gradient checkpointing for sequence length of 1
# /Users/estakempf/Tech/Bachelorarbeit/graphcast-xai/.venv/lib/python3.12/site-packages/graphcast/autoregressive.py:115: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   num_inputs = inputs.dims['time']
# /Users/estakempf/Tech/Bachelorarbeit/graphcast-xai/.venv/lib/python3.12/site-packages/graphcast/rollout.py:205: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   num_inputs = prev_inputs.dims["time"]
# Prediction saved to: ../data/feature_occlusion/wind_levels_regions/masked_('u_component_of_wind', 'v_component_of_wind')_lev925_reghigh_pressure_south_tnone.nc
# 🚀 Running forecast with mask on: vars=('u_component_of_wind', 'v_component_of_wind'), levels=925, regions=low_pressure_north, time_steps=None
# 📦 Using checkpoint: graphcast/params/GraphCast_small - ERA5 1979-2015 - resolution 1.0 - pressure levels 13 - mesh 2to5 - precipitation input and output.npz
# /Users/estakempf/Tech/Bachelorarbeit/graphcast-xai/.venv/lib/python3.12/site-packages/graphcast/rollout.py:127: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   num_target_steps = targets_template.dims["time"]
# /Users/estakempf/Tech/Bachelorarbeit/graphcast-xai/.venv/lib/python3.12/site-packages/graphcast/autoregressive.py:202: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   scan_length = targets_template.dims['time']
# WARNING:absl:Skipping gradient checkpointing for sequence length of 1
# /Users/estakempf/Tech/Bachelorarbeit/graphcast-xai/.venv/lib/python3.12/site-packages/graphcast/autoregressive.py:115: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   num_inputs = inputs.dims['time']
# /Users/estakempf/Tech/Bachelorarbeit/graphcast-xai/.venv/lib/python3.12/site-packages/graphcast/rollout.py:205: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   num_inputs = prev_inputs.dims["time"]
# Prediction saved to: ../data/feature_occlusion/wind_levels_regions/masked_('u_component_of_wind', 'v_component_of_wind')_lev925_reglow_pressure_north_tnone.nc
# 🚀 Running forecast with mask on: vars=('u_component_of_wind', 'v_component_of_wind'), levels=850, regions=atlantic_jet_stream, time_steps=None
# 📦 Using checkpoint: graphcast/params/GraphCast_small - ERA5 1979-2015 - resolution 1.0 - pressure levels 13 - mesh 2to5 - precipitation input and output.npz
# /Users/estakempf/Tech/Bachelorarbeit/graphcast-xai/.venv/lib/python3.12/site-packages/graphcast/rollout.py:127: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   num_target_steps = targets_template.dims["time"]
# /Users/estakempf/Tech/Bachelorarbeit/graphcast-xai/.venv/lib/python3.12/site-packages/graphcast/autoregressive.py:202: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   scan_length = targets_template.dims['time']
# WARNING:absl:Skipping gradient checkpointing for sequence length of 1
# /Users/estakempf/Tech/Bachelorarbeit/graphcast-xai/.venv/lib/python3.12/site-packages/graphcast/autoregressive.py:115: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   num_inputs = inputs.dims['time']
# /Users/estakempf/Tech/Bachelorarbeit/graphcast-xai/.venv/lib/python3.12/site-packages/graphcast/rollout.py:205: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   num_inputs = prev_inputs.dims["time"]
# Prediction saved to: ../data/feature_occlusion/wind_levels_regions/masked_('u_component_of_wind', 'v_component_of_wind')_lev850_regatlantic_jet_stream_tnone.nc
# 🚀 Running forecast with mask on: vars=('u_component_of_wind', 'v_component_of_wind'), levels=850, regions=storm_core, time_steps=None
# 📦 Using checkpoint: graphcast/params/GraphCast_small - ERA5 1979-2015 - resolution 1.0 - pressure levels 13 - mesh 2to5 - precipitation input and output.npz
# /Users/estakempf/Tech/Bachelorarbeit/graphcast-xai/.venv/lib/python3.12/site-packages/graphcast/rollout.py:127: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   num_target_steps = targets_template.dims["time"]
# /Users/estakempf/Tech/Bachelorarbeit/graphcast-xai/.venv/lib/python3.12/site-packages/graphcast/autoregressive.py:202: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   scan_length = targets_template.dims['time']
# WARNING:absl:Skipping gradient checkpointing for sequence length of 1
# /Users/estakempf/Tech/Bachelorarbeit/graphcast-xai/.venv/lib/python3.12/site-packages/graphcast/autoregressive.py:115: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   num_inputs = inputs.dims['time']
# /Users/estakempf/Tech/Bachelorarbeit/graphcast-xai/.venv/lib/python3.12/site-packages/graphcast/rollout.py:205: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   num_inputs = prev_inputs.dims["time"]
# Prediction saved to: ../data/feature_occlusion/wind_levels_regions/masked_('u_component_of_wind', 'v_component_of_wind')_lev850_regstorm_core_tnone.nc
# 🚀 Running forecast with mask on: vars=('u_component_of_wind', 'v_component_of_wind'), levels=850, regions=dynamic_uljs, time_steps=None
# 📦 Using checkpoint: graphcast/params/GraphCast_small - ERA5 1979-2015 - resolution 1.0 - pressure levels 13 - mesh 2to5 - precipitation input and output.npz
# /Users/estakempf/Tech/Bachelorarbeit/graphcast-xai/.venv/lib/python3.12/site-packages/graphcast/rollout.py:127: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   num_target_steps = targets_template.dims["time"]
# /Users/estakempf/Tech/Bachelorarbeit/graphcast-xai/.venv/lib/python3.12/site-packages/graphcast/autoregressive.py:202: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   scan_length = targets_template.dims['time']
# WARNING:absl:Skipping gradient checkpointing for sequence length of 1
# /Users/estakempf/Tech/Bachelorarbeit/graphcast-xai/.venv/lib/python3.12/site-packages/graphcast/autoregressive.py:115: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   num_inputs = inputs.dims['time']
# /Users/estakempf/Tech/Bachelorarbeit/graphcast-xai/.venv/lib/python3.12/site-packages/graphcast/rollout.py:205: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   num_inputs = prev_inputs.dims["time"]
# Prediction saved to: ../data/feature_occlusion/wind_levels_regions/masked_('u_component_of_wind', 'v_component_of_wind')_lev850_regdynamic_uljs_tnone.nc
# 🚀 Running forecast with mask on: vars=('u_component_of_wind', 'v_component_of_wind'), levels=850, regions=high_pressure_south, time_steps=None
# 📦 Using checkpoint: graphcast/params/GraphCast_small - ERA5 1979-2015 - resolution 1.0 - pressure levels 13 - mesh 2to5 - precipitation input and output.npz
# /Users/estakempf/Tech/Bachelorarbeit/graphcast-xai/.venv/lib/python3.12/site-packages/graphcast/rollout.py:127: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   num_target_steps = targets_template.dims["time"]
# /Users/estakempf/Tech/Bachelorarbeit/graphcast-xai/.venv/lib/python3.12/site-packages/graphcast/autoregressive.py:202: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   scan_length = targets_template.dims['time']
# WARNING:absl:Skipping gradient checkpointing for sequence length of 1
# /Users/estakempf/Tech/Bachelorarbeit/graphcast-xai/.venv/lib/python3.12/site-packages/graphcast/autoregressive.py:115: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   num_inputs = inputs.dims['time']
# /Users/estakempf/Tech/Bachelorarbeit/graphcast-xai/.venv/lib/python3.12/site-packages/graphcast/rollout.py:205: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   num_inputs = prev_inputs.dims["time"]
# Prediction saved to: ../data/feature_occlusion/wind_levels_regions/masked_('u_component_of_wind', 'v_component_of_wind')_lev850_reghigh_pressure_south_tnone.nc
# 🚀 Running forecast with mask on: vars=('u_component_of_wind', 'v_component_of_wind'), levels=850, regions=low_pressure_north, time_steps=None
# 📦 Using checkpoint: graphcast/params/GraphCast_small - ERA5 1979-2015 - resolution 1.0 - pressure levels 13 - mesh 2to5 - precipitation input and output.npz
# /Users/estakempf/Tech/Bachelorarbeit/graphcast-xai/.venv/lib/python3.12/site-packages/graphcast/rollout.py:127: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   num_target_steps = targets_template.dims["time"]
# /Users/estakempf/Tech/Bachelorarbeit/graphcast-xai/.venv/lib/python3.12/site-packages/graphcast/autoregressive.py:202: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   scan_length = targets_template.dims['time']
# WARNING:absl:Skipping gradient checkpointing for sequence length of 1
# /Users/estakempf/Tech/Bachelorarbeit/graphcast-xai/.venv/lib/python3.12/site-packages/graphcast/autoregressive.py:115: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   num_inputs = inputs.dims['time']
# /Users/estakempf/Tech/Bachelorarbeit/graphcast-xai/.venv/lib/python3.12/site-packages/graphcast/rollout.py:205: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   num_inputs = prev_inputs.dims["time"]
# Prediction saved to: ../data/feature_occlusion/wind_levels_regions/masked_('u_component_of_wind', 'v_component_of_wind')_lev850_reglow_pressure_north_tnone.nc
# 🚀 Running forecast with mask on: vars=('u_component_of_wind', 'v_component_of_wind'), levels=700, regions=atlantic_jet_stream, time_steps=None
# 📦 Using checkpoint: graphcast/params/GraphCast_small - ERA5 1979-2015 - resolution 1.0 - pressure levels 13 - mesh 2to5 - precipitation input and output.npz
# /Users/estakempf/Tech/Bachelorarbeit/graphcast-xai/.venv/lib/python3.12/site-packages/graphcast/rollout.py:127: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   num_target_steps = targets_template.dims["time"]
# /Users/estakempf/Tech/Bachelorarbeit/graphcast-xai/.venv/lib/python3.12/site-packages/graphcast/autoregressive.py:202: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   scan_length = targets_template.dims['time']
# WARNING:absl:Skipping gradient checkpointing for sequence length of 1
# /Users/estakempf/Tech/Bachelorarbeit/graphcast-xai/.venv/lib/python3.12/site-packages/graphcast/autoregressive.py:115: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   num_inputs = inputs.dims['time']
# /Users/estakempf/Tech/Bachelorarbeit/graphcast-xai/.venv/lib/python3.12/site-packages/graphcast/rollout.py:205: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   num_inputs = prev_inputs.dims["time"]
# Prediction saved to: ../data/feature_occlusion/wind_levels_regions/masked_('u_component_of_wind', 'v_component_of_wind')_lev700_regatlantic_jet_stream_tnone.nc
# 🚀 Running forecast with mask on: vars=('u_component_of_wind', 'v_component_of_wind'), levels=700, regions=storm_core, time_steps=None
# 📦 Using checkpoint: graphcast/params/GraphCast_small - ERA5 1979-2015 - resolution 1.0 - pressure levels 13 - mesh 2to5 - precipitation input and output.npz
# /Users/estakempf/Tech/Bachelorarbeit/graphcast-xai/.venv/lib/python3.12/site-packages/graphcast/rollout.py:127: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   num_target_steps = targets_template.dims["time"]
# /Users/estakempf/Tech/Bachelorarbeit/graphcast-xai/.venv/lib/python3.12/site-packages/graphcast/autoregressive.py:202: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   scan_length = targets_template.dims['time']
# WARNING:absl:Skipping gradient checkpointing for sequence length of 1
# /Users/estakempf/Tech/Bachelorarbeit/graphcast-xai/.venv/lib/python3.12/site-packages/graphcast/autoregressive.py:115: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   num_inputs = inputs.dims['time']
# /Users/estakempf/Tech/Bachelorarbeit/graphcast-xai/.venv/lib/python3.12/site-packages/graphcast/rollout.py:205: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   num_inputs = prev_inputs.dims["time"]
# Prediction saved to: ../data/feature_occlusion/wind_levels_regions/masked_('u_component_of_wind', 'v_component_of_wind')_lev700_regstorm_core_tnone.nc
# 🚀 Running forecast with mask on: vars=('u_component_of_wind', 'v_component_of_wind'), levels=700, regions=dynamic_uljs, time_steps=None
# 📦 Using checkpoint: graphcast/params/GraphCast_small - ERA5 1979-2015 - resolution 1.0 - pressure levels 13 - mesh 2to5 - precipitation input and output.npz
# /Users/estakempf/Tech/Bachelorarbeit/graphcast-xai/.venv/lib/python3.12/site-packages/graphcast/rollout.py:127: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   num_target_steps = targets_template.dims["time"]
# /Users/estakempf/Tech/Bachelorarbeit/graphcast-xai/.venv/lib/python3.12/site-packages/graphcast/autoregressive.py:202: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   scan_length = targets_template.dims['time']
# WARNING:absl:Skipping gradient checkpointing for sequence length of 1
# /Users/estakempf/Tech/Bachelorarbeit/graphcast-xai/.venv/lib/python3.12/site-packages/graphcast/autoregressive.py:115: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   num_inputs = inputs.dims['time']
# /Users/estakempf/Tech/Bachelorarbeit/graphcast-xai/.venv/lib/python3.12/site-packages/graphcast/rollout.py:205: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   num_inputs = prev_inputs.dims["time"]
# Prediction saved to: ../data/feature_occlusion/wind_levels_regions/masked_('u_component_of_wind', 'v_component_of_wind')_lev700_regdynamic_uljs_tnone.nc
# 🚀 Running forecast with mask on: vars=('u_component_of_wind', 'v_component_of_wind'), levels=700, regions=high_pressure_south, time_steps=None
# 📦 Using checkpoint: graphcast/params/GraphCast_small - ERA5 1979-2015 - resolution 1.0 - pressure levels 13 - mesh 2to5 - precipitation input and output.npz
# /Users/estakempf/Tech/Bachelorarbeit/graphcast-xai/.venv/lib/python3.12/site-packages/graphcast/rollout.py:127: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   num_target_steps = targets_template.dims["time"]
# /Users/estakempf/Tech/Bachelorarbeit/graphcast-xai/.venv/lib/python3.12/site-packages/graphcast/autoregressive.py:202: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   scan_length = targets_template.dims['time']
# WARNING:absl:Skipping gradient checkpointing for sequence length of 1
# /Users/estakempf/Tech/Bachelorarbeit/graphcast-xai/.venv/lib/python3.12/site-packages/graphcast/autoregressive.py:115: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   num_inputs = inputs.dims['time']
# /Users/estakempf/Tech/Bachelorarbeit/graphcast-xai/.venv/lib/python3.12/site-packages/graphcast/rollout.py:205: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   num_inputs = prev_inputs.dims["time"]
# Prediction saved to: ../data/feature_occlusion/wind_levels_regions/masked_('u_component_of_wind', 'v_component_of_wind')_lev700_reghigh_pressure_south_tnone.nc
# 🚀 Running forecast with mask on: vars=('u_component_of_wind', 'v_component_of_wind'), levels=700, regions=low_pressure_north, time_steps=None
# 📦 Using checkpoint: graphcast/params/GraphCast_small - ERA5 1979-2015 - resolution 1.0 - pressure levels 13 - mesh 2to5 - precipitation input and output.npz
# /Users/estakempf/Tech/Bachelorarbeit/graphcast-xai/.venv/lib/python3.12/site-packages/graphcast/rollout.py:127: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   num_target_steps = targets_template.dims["time"]
# /Users/estakempf/Tech/Bachelorarbeit/graphcast-xai/.venv/lib/python3.12/site-packages/graphcast/autoregressive.py:202: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   scan_length = targets_template.dims['time']
# WARNING:absl:Skipping gradient checkpointing for sequence length of 1
# /Users/estakempf/Tech/Bachelorarbeit/graphcast-xai/.venv/lib/python3.12/site-packages/graphcast/autoregressive.py:115: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   num_inputs = inputs.dims['time']
# /Users/estakempf/Tech/Bachelorarbeit/graphcast-xai/.venv/lib/python3.12/site-packages/graphcast/rollout.py:205: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   num_inputs = prev_inputs.dims["time"]
# Prediction saved to: ../data/feature_occlusion/wind_levels_regions/masked_('u_component_of_wind', 'v_component_of_wind')_lev700_reglow_pressure_north_tnone.nc
# 🚀 Running forecast with mask on: vars=('u_component_of_wind', 'v_component_of_wind'), levels=600, regions=atlantic_jet_stream, time_steps=None
# 📦 Using checkpoint: graphcast/params/GraphCast_small - ERA5 1979-2015 - resolution 1.0 - pressure levels 13 - mesh 2to5 - precipitation input and output.npz
# /Users/estakempf/Tech/Bachelorarbeit/graphcast-xai/.venv/lib/python3.12/site-packages/graphcast/rollout.py:127: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   num_target_steps = targets_template.dims["time"]
# /Users/estakempf/Tech/Bachelorarbeit/graphcast-xai/.venv/lib/python3.12/site-packages/graphcast/autoregressive.py:202: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   scan_length = targets_template.dims['time']
# WARNING:absl:Skipping gradient checkpointing for sequence length of 1
# /Users/estakempf/Tech/Bachelorarbeit/graphcast-xai/.venv/lib/python3.12/site-packages/graphcast/autoregressive.py:115: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   num_inputs = inputs.dims['time']
# /Users/estakempf/Tech/Bachelorarbeit/graphcast-xai/.venv/lib/python3.12/site-packages/graphcast/rollout.py:205: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   num_inputs = prev_inputs.dims["time"]
# Prediction saved to: ../data/feature_occlusion/wind_levels_regions/masked_('u_component_of_wind', 'v_component_of_wind')_lev600_regatlantic_jet_stream_tnone.nc
# 🚀 Running forecast with mask on: vars=('u_component_of_wind', 'v_component_of_wind'), levels=600, regions=storm_core, time_steps=None
# 📦 Using checkpoint: graphcast/params/GraphCast_small - ERA5 1979-2015 - resolution 1.0 - pressure levels 13 - mesh 2to5 - precipitation input and output.npz
# /Users/estakempf/Tech/Bachelorarbeit/graphcast-xai/.venv/lib/python3.12/site-packages/graphcast/rollout.py:127: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   num_target_steps = targets_template.dims["time"]
# /Users/estakempf/Tech/Bachelorarbeit/graphcast-xai/.venv/lib/python3.12/site-packages/graphcast/autoregressive.py:202: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   scan_length = targets_template.dims['time']
# WARNING:absl:Skipping gradient checkpointing for sequence length of 1
# /Users/estakempf/Tech/Bachelorarbeit/graphcast-xai/.venv/lib/python3.12/site-packages/graphcast/autoregressive.py:115: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   num_inputs = inputs.dims['time']
# /Users/estakempf/Tech/Bachelorarbeit/graphcast-xai/.venv/lib/python3.12/site-packages/graphcast/rollout.py:205: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   num_inputs = prev_inputs.dims["time"]
# Prediction saved to: ../data/feature_occlusion/wind_levels_regions/masked_('u_component_of_wind', 'v_component_of_wind')_lev600_regstorm_core_tnone.nc
# 🚀 Running forecast with mask on: vars=('u_component_of_wind', 'v_component_of_wind'), levels=600, regions=dynamic_uljs, time_steps=None
# 📦 Using checkpoint: graphcast/params/GraphCast_small - ERA5 1979-2015 - resolution 1.0 - pressure levels 13 - mesh 2to5 - precipitation input and output.npz
# /Users/estakempf/Tech/Bachelorarbeit/graphcast-xai/.venv/lib/python3.12/site-packages/graphcast/rollout.py:127: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   num_target_steps = targets_template.dims["time"]
# ...
# /Users/estakempf/Tech/Bachelorarbeit/graphcast-xai/.venv/lib/python3.12/site-packages/graphcast/autoregressive.py:115: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   num_inputs = inputs.dims['time']
# /Users/estakempf/Tech/Bachelorarbeit/graphcast-xai/.venv/lib/python3.12/site-packages/graphcast/rollout.py:205: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   num_inputs = prev_inputs.dims["time"]
# Prediction saved to: ../data/feature_occlusion/wind_levels_regions/masked_('u_component_of_wind', 'v_component_of_wind')_lev100_regdynamic_uljs_tnone.nc
# 🚀 Running forecast with mask on: vars=('u_component_of_wind', 'v_component_of_wind'), levels=100, regions=high_pressure_south, time_steps=None
# 📦 Using checkpoint: graphcast/params/GraphCast_small - ERA5 1979-2015 - resolution 1.0 - pressure levels 13 - mesh 2to5 - precipitation input and output.npz
# /Users/estakempf/Tech/Bachelorarbeit/graphcast-xai/.venv/lib/python3.12/site-packages/graphcast/rollout.py:127: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   num_target_steps = targets_template.dims["time"]
# /Users/estakempf/Tech/Bachelorarbeit/graphcast-xai/.venv/lib/python3.12/site-packages/graphcast/autoregressive.py:202: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   scan_length = targets_template.dims['time']
# WARNING:absl:Skipping gradient checkpointing for sequence length of 1
# /Users/estakempf/Tech/Bachelorarbeit/graphcast-xai/.venv/lib/python3.12/site-packages/graphcast/autoregressive.py:115: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   num_inputs = inputs.dims['time']
# /Users/estakempf/Tech/Bachelorarbeit/graphcast-xai/.venv/lib/python3.12/site-packages/graphcast/rollout.py:205: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   num_inputs = prev_inputs.dims["time"]
# Prediction saved to: ../data/feature_occlusion/wind_levels_regions/masked_('u_component_of_wind', 'v_component_of_wind')_lev100_reghigh_pressure_south_tnone.nc
# 🚀 Running forecast with mask on: vars=('u_component_of_wind', 'v_component_of_wind'), levels=100, regions=low_pressure_north, time_steps=None
# 📦 Using checkpoint: graphcast/params/GraphCast_small - ERA5 1979-2015 - resolution 1.0 - pressure levels 13 - mesh 2to5 - precipitation input and output.npz
# /Users/estakempf/Tech/Bachelorarbeit/graphcast-xai/.venv/lib/python3.12/site-packages/graphcast/rollout.py:127: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   num_target_steps = targets_template.dims["time"]
# /Users/estakempf/Tech/Bachelorarbeit/graphcast-xai/.venv/lib/python3.12/site-packages/graphcast/autoregressive.py:202: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   scan_length = targets_template.dims['time']
# WARNING:absl:Skipping gradient checkpointing for sequence length of 1
# /Users/estakempf/Tech/Bachelorarbeit/graphcast-xai/.venv/lib/python3.12/site-packages/graphcast/autoregressive.py:115: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   num_inputs = inputs.dims['time']
# /Users/estakempf/Tech/Bachelorarbeit/graphcast-xai/.venv/lib/python3.12/site-packages/graphcast/rollout.py:205: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   num_inputs = prev_inputs.dims["time"]
# Prediction saved to: ../data/feature_occlusion/wind_levels_regions/masked_('u_component_of_wind', 'v_component_of_wind')_lev100_reglow_pressure_north_tnone.nc
# 🚀 Running forecast with mask on: vars=('u_component_of_wind', 'v_component_of_wind'), levels=50, regions=atlantic_jet_stream, time_steps=None
# 📦 Using checkpoint: graphcast/params/GraphCast_small - ERA5 1979-2015 - resolution 1.0 - pressure levels 13 - mesh 2to5 - precipitation input and output.npz
# /Users/estakempf/Tech/Bachelorarbeit/graphcast-xai/.venv/lib/python3.12/site-packages/graphcast/rollout.py:127: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   num_target_steps = targets_template.dims["time"]
# /Users/estakempf/Tech/Bachelorarbeit/graphcast-xai/.venv/lib/python3.12/site-packages/graphcast/autoregressive.py:202: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   scan_length = targets_template.dims['time']
# WARNING:absl:Skipping gradient checkpointing for sequence length of 1
# /Users/estakempf/Tech/Bachelorarbeit/graphcast-xai/.venv/lib/python3.12/site-packages/graphcast/autoregressive.py:115: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   num_inputs = inputs.dims['time']
# /Users/estakempf/Tech/Bachelorarbeit/graphcast-xai/.venv/lib/python3.12/site-packages/graphcast/rollout.py:205: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   num_inputs = prev_inputs.dims["time"]
# Prediction saved to: ../data/feature_occlusion/wind_levels_regions/masked_('u_component_of_wind', 'v_component_of_wind')_lev50_regatlantic_jet_stream_tnone.nc
# 🚀 Running forecast with mask on: vars=('u_component_of_wind', 'v_component_of_wind'), levels=50, regions=storm_core, time_steps=None
# 📦 Using checkpoint: graphcast/params/GraphCast_small - ERA5 1979-2015 - resolution 1.0 - pressure levels 13 - mesh 2to5 - precipitation input and output.npz
# /Users/estakempf/Tech/Bachelorarbeit/graphcast-xai/.venv/lib/python3.12/site-packages/graphcast/rollout.py:127: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   num_target_steps = targets_template.dims["time"]
# /Users/estakempf/Tech/Bachelorarbeit/graphcast-xai/.venv/lib/python3.12/site-packages/graphcast/autoregressive.py:202: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   scan_length = targets_template.dims['time']
# WARNING:absl:Skipping gradient checkpointing for sequence length of 1
# /Users/estakempf/Tech/Bachelorarbeit/graphcast-xai/.venv/lib/python3.12/site-packages/graphcast/autoregressive.py:115: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   num_inputs = inputs.dims['time']
# /Users/estakempf/Tech/Bachelorarbeit/graphcast-xai/.venv/lib/python3.12/site-packages/graphcast/rollout.py:205: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   num_inputs = prev_inputs.dims["time"]
# Prediction saved to: ../data/feature_occlusion/wind_levels_regions/masked_('u_component_of_wind', 'v_component_of_wind')_lev50_regstorm_core_tnone.nc
# 🚀 Running forecast with mask on: vars=('u_component_of_wind', 'v_component_of_wind'), levels=50, regions=dynamic_uljs, time_steps=None
# 📦 Using checkpoint: graphcast/params/GraphCast_small - ERA5 1979-2015 - resolution 1.0 - pressure levels 13 - mesh 2to5 - precipitation input and output.npz
# /Users/estakempf/Tech/Bachelorarbeit/graphcast-xai/.venv/lib/python3.12/site-packages/graphcast/rollout.py:127: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   num_target_steps = targets_template.dims["time"]
# /Users/estakempf/Tech/Bachelorarbeit/graphcast-xai/.venv/lib/python3.12/site-packages/graphcast/autoregressive.py:202: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   scan_length = targets_template.dims['time']
# WARNING:absl:Skipping gradient checkpointing for sequence length of 1
# /Users/estakempf/Tech/Bachelorarbeit/graphcast-xai/.venv/lib/python3.12/site-packages/graphcast/autoregressive.py:115: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   num_inputs = inputs.dims['time']
# /Users/estakempf/Tech/Bachelorarbeit/graphcast-xai/.venv/lib/python3.12/site-packages/graphcast/rollout.py:205: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   num_inputs = prev_inputs.dims["time"]
# Prediction saved to: ../data/feature_occlusion/wind_levels_regions/masked_('u_component_of_wind', 'v_component_of_wind')_lev50_regdynamic_uljs_tnone.nc
# 🚀 Running forecast with mask on: vars=('u_component_of_wind', 'v_component_of_wind'), levels=50, regions=high_pressure_south, time_steps=None
# 📦 Using checkpoint: graphcast/params/GraphCast_small - ERA5 1979-2015 - resolution 1.0 - pressure levels 13 - mesh 2to5 - precipitation input and output.npz
# /Users/estakempf/Tech/Bachelorarbeit/graphcast-xai/.venv/lib/python3.12/site-packages/graphcast/rollout.py:127: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   num_target_steps = targets_template.dims["time"]
# /Users/estakempf/Tech/Bachelorarbeit/graphcast-xai/.venv/lib/python3.12/site-packages/graphcast/autoregressive.py:202: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   scan_length = targets_template.dims['time']
# WARNING:absl:Skipping gradient checkpointing for sequence length of 1
# /Users/estakempf/Tech/Bachelorarbeit/graphcast-xai/.venv/lib/python3.12/site-packages/graphcast/autoregressive.py:115: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   num_inputs = inputs.dims['time']
# /Users/estakempf/Tech/Bachelorarbeit/graphcast-xai/.venv/lib/python3.12/site-packages/graphcast/rollout.py:205: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   num_inputs = prev_inputs.dims["time"]
# Prediction saved to: ../data/feature_occlusion/wind_levels_regions/masked_('u_component_of_wind', 'v_component_of_wind')_lev50_reghigh_pressure_south_tnone.nc
# 🚀 Running forecast with mask on: vars=('u_component_of_wind', 'v_component_of_wind'), levels=50, regions=low_pressure_north, time_steps=None
# 📦 Using checkpoint: graphcast/params/GraphCast_small - ERA5 1979-2015 - resolution 1.0 - pressure levels 13 - mesh 2to5 - precipitation input and output.npz
# /Users/estakempf/Tech/Bachelorarbeit/graphcast-xai/.venv/lib/python3.12/site-packages/graphcast/rollout.py:127: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   num_target_steps = targets_template.dims["time"]
# /Users/estakempf/Tech/Bachelorarbeit/graphcast-xai/.venv/lib/python3.12/site-packages/graphcast/autoregressive.py:202: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   scan_length = targets_template.dims['time']
# WARNING:absl:Skipping gradient checkpointing for sequence length of 1
# /Users/estakempf/Tech/Bachelorarbeit/graphcast-xai/.venv/lib/python3.12/site-packages/graphcast/autoregressive.py:115: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   num_inputs = inputs.dims['time']
# /Users/estakempf/Tech/Bachelorarbeit/graphcast-xai/.venv/lib/python3.12/site-packages/graphcast/rollout.py:205: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   num_inputs = prev_inputs.dims["time"]
# Prediction saved to: ../data/feature_occlusion/wind_levels_regions/masked_('u_component_of_wind', 'v_component_of_wind')_lev50_reglow_pressure_north_tnone.nc
